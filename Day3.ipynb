# %%
class Student(object):
    
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def study(self, course_name):
        print('%s正在学习%s.' % (self.name, course_name))
        
    def watch_movie(self):
        if self.age < 18:
            print('%s只能观看《熊出没》.' % self.name)
        else:
            print('%s正在观看岛国爱情大电影.' % self.name)
            
def main():
    # 创建学生对象并指定姓名和年龄
    stu1 = Student('骆昊', 38)
    # 给对象发study消息
    stu1.study('Python程序设计')
    # 给对象发watch_av消息
    stu1.watch_movie()
    stu2 = Student('王大锤', 15)
    stu2.study('思想品德')
    stu2.watch_movie()


if __name__ == '__main__':
    main()
# Out:
# 骆昊正在学习Python程序设计.
# 骆昊正在观看岛国爱情大电影.
# 王大锤正在学习思想品德.
# 王大锤只能观看《熊出没》.

# %%
class Test:
    
    def __init__(self, foo):
        self.__foo = foo
    
    #将bar设置为私有的方法
    def __bar(self):
        print(self.__foo)
        print('__bar')
        
def main():
    test = Test('hello')
    test._Test__bar()
    print(test._Test__foo)
    
if __name__ == '__main__':
    main()
# Out:
# hello
# __bar
# hello

# %%
#练习1:定义一个类描述数字时钟

from time import sleep

class Clock(object):
    """数字时钟"""
    
    def __init__(self, hour = 0, minute = 0, second = 0):
        self._hour = hour
        self._minute = minute
        self._second = second
        
    def run(self):
        """走字"""
        self._second += 1
        if self._second == 60:
            self._second = 0
            self._minute += 1
            if self._minute == 60:
                self._minute = 0
                self._hour += 1
                if self._hour == 24:
                    self._hour = 0
                
    def show(self):
        """显示时间"""
        return '%02d:%02d:%02d' % \
               (self._hour, self._minute, self._second)
    
def main():
    clock = Clock(23, 59, 58)
    while True:
        print(clock.show())
        sleep(1)
        clock.run()
        
if __name__ == '__main__':
    main()
# Out:
# 23:59:58
# 23:59:59
# 00:00:00
# 00:00:01
# 00:00:02
# 00:00:03
# 00:00:04
# 00:00:05
# 00:00:06
# 00:00:07
# 00:00:08
# 00:00:09
# 00:00:10
# 00:00:11
# 00:00:12
# 00:00:13
# 00:00:14
# 00:00:15
# 00:00:16
# 00:00:17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-126ea8c8de8e> in <module>
#      36
#      37 if __name__ == '__main__':
# ---> 38     main()
#
# <ipython-input-29-126ea8c8de8e> in main()
#      32     while True:
#      33         print(clock.show())
# ---> 34         sleep(1)
#      35         clock.run()
#      36
#
# KeyboardInterrupt:

# %%
from time import sleep


class Clock(object):
    """数字时钟"""

    def __init__(self, hour=0, minute=0, second=0):
        """初始化方法

        :param hour: 时
        :param minute: 分
        :param second: 秒
        """
        self._hour = hour
        self._minute = minute
        self._second = second

    def run(self):
        """走字"""
        self._second += 1
        if self._second == 60:
            self._second = 0
            self._minute += 1
            if self._minute == 60:
                self._minute = 0
                self._hour += 1
                if self._hour == 24:
                    self._hour = 0

    def show(self):
        """显示时间"""
        return '%02d:%02d:%02d' % \
               (self._hour, self._minute, self._second)


def main():
    clock = Clock(23, 59, 58)
    while True:
        print(clock.show())
        sleep(1)
        clock.run()


if __name__ == '__main__':
    main()
# Out:
# 23:59:58
# 23:59:59
# 00:00:00
# 00:00:01
# 00:00:02
# 00:00:03
# 00:00:04
# 00:00:05
# 00:00:06
# 00:00:07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-bd10172a6246> in <module>
#      43
#      44 if __name__ == '__main__':
# ---> 45     main()
#
# <ipython-input-27-bd10172a6246> in main()
#      38     while True:
#      39         print(clock.show())
# ---> 40         sleep(1)
#      41         clock.run()
#      42
#
# KeyboardInterrupt:

# %%
class Point(object):
    def __init__(self, x, y):
        self._x = x
        self._y = y
        
p1 = Point(1, 2)
p1._x = 3
print(p1._x)
print(p1._y)
# Out:
# 3
# 2

# %%
#属性的getter和setter方法
class Person(object):
    def __init__(self, name, age):
        self._name = name
        self._age = age
        
    #访问器 - getter方法
    @property
    def name(self):
        return self._name

        
Romeo = Person('Romeo', 20)
print(Romeo.name)

#AttributeError: can't set attribute
#Romeo.name = 'Liu'

#AttributeError: 'Person' object has no attribute 'age'
#print(Romeo.age) 

print(Romeo._age)

Romeo._is_gay = True
#可以给Romeo这个新的对象添加新的对象
#如果需要限定，需要定义_slot_
# Out:
# Romeo
# 20

# %% [markdown]
# ##### __slots__

# %%
class Person(object):
    # 限定Person对象只能绑定_name, _age和_gender属性
    __slots__ = ('_name', '_age', '_gender')
    
    def __init__(self, name, age, gender):
        self._name = name
        self._age = age
        
    @property
    def name(self):
        return self._name
    
    @property
    def age(self):
        return self._age
    
    @property
    def gender(self):
        return self._gender
    
    @name.setter
    def name(self, name):
        self._name = name
        
    @age.setter
    def age(self, age):
        self._age = age
        
    @gender.setter
    def gender(self, gender):
        self._gender = gender
    
def main():
    Romeo = Person('Romeo', 20, 'male')
    Romeo._gender = 'female'
    Romeo.name = 'Liu'
    print(Romeo.name)
    
    #AttributeError: 'Person' object has no attribute '_is_gay'
    #Romeo._is_gay = True
    
if __name__ == '__main__':
    main()
# Out:
# Liu

# %%
from math import sqrt

#静态方法
class Triangle(object):
    def __init__(self, a, b, c):
        self._a = a
        self._b = b
        self._c = c
    
    #静态方法，独立于对象之外的方法（不依赖于对象）
    @staticmethod
    def is_valid(a, b, c):
        return a + b > c and b + c > a and a + c > b
    
    def perimeter(self):
        return self._a + self._b + self._c
    
    def area(self):
        p = (self._a + self._b + self._c) / 2
        return sqrt(p * (p - self._a) * (p - self._b) * (p - self._c))
    
def main():
    a, b, c = 3, 4, 5
    #静态方法直接向类传递信息而不是向对象传递
    if Triangle.is_valid(a, b, c):
        triangle = Triangle(a, b, c)
        print(triangle.area())
        print(triangle.perimeter())
    else:
        print("不能构成三角形")
        
if __name__ == '__main__':
    main()
# Out:
# 6.0
# 12

# %%
#类方法

from time import sleep, localtime, time


class Clock(object):
    """数字时钟"""

    def __init__(self, hour=0, minute=0, second=0):
        """初始化方法

        :param hour: 时
        :param minute: 分
        :param second: 秒
        """
        self._hour = hour
        self._minute = minute
        self._second = second
    
    #类方法，第一个变量约定为cls，将类看成一个对象
    #返回该类的方法？
    #类方法的第一个参数约定名为cls，它代表的是当前类相关的信息的对象
    @classmethod
    def now(cls):
        ctime = localtime(time())
        return cls(ctime.tm_hour, ctime.tm_min, ctime.tm_sec)

    def run(self):
        """走字"""
        self._second += 1
        if self._second == 60:
            self._second = 0
            self._minute += 1
            if self._minute == 60:
                self._minute = 0
                self._hour += 1
                if self._hour == 24:
                    self._hour = 0

    def show(self):
        """显示时间"""
        return '%02d:%02d:%02d' % \
               (self._hour, self._minute, self._second)


def main():
    clock = Clock.now()
    while True:
        print(clock.show())
        sleep(1)
        clock.run()


if __name__ == '__main__':
    main()
# Out:
# 17:03:43
# 17:03:44
# 17:03:45
# 17:03:46
# 17:03:47
# 17:03:48
# 17:03:49
# 17:03:50
# 17:03:51
# 17:03:52
# 17:03:53
# 17:03:54
# 17:03:55
# 17:03:56
# 17:03:57
# 17:03:58
# 17:03:59
# 17:04:00
# 17:04:01
# 17:04:02
# 17:04:03
# 17:04:04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-b60a101bf06a> in <module>
#      52
#      53 if __name__ == '__main__':
# ---> 54     main()
#
# <ipython-input-67-b60a101bf06a> in main()
#      47     while True:
#      48         print(clock.show())
# ---> 49         sleep(1)
#      50         clock.run()
#      51
#
# KeyboardInterrupt:

# %% [markdown]
# # 继承与多态
# ## 简单的说，类和类之间的关系有三种：is-a、has-a和use-a关系。

# %%
#继承的例子

class Person(object):
    def __init__(self, name, age):
        self._name = name
        self._age = age
        
    @property
    def name(self):
        return self._name
    
    @property
    def age(self):
        return self._age
    
    #修改器是_age修改的唯一途径
    @age.setter
    def age(self, age):
        self._age = age
        
    def play(self):
        print("%s正在愉快地玩耍." % (self._name))
        
class Student(Person):
    """学生"""
    
    def __init__(self, name, age, grade):
        super().__init__(name, age)
        self._grade = grade
        
    @property
    def grade(self):
        return self._grade
        
    @grade.setter
    def grade(self, grade):
        self._grade = grade
    
    def study(self, course):
        print("%s is studying %s." % (self._name, course))

class Teacher(Person):
    """老师"""
    
    def __init__(self, name, age, title):
        super().__init__(name, age)
        self._title = title
        
    @property
    def title(self):
        return self._title

    @title.setter
    def title(self, title):
        self._title = title

    def teach(self, course):
        print('%s%s正在讲%s.' % (self._name, self._title, course))

def main():
    stu = Student('王大锤', 15, '初三')
    stu.study('数学')
    t = Teacher('骆昊', 38, '老叫兽')
    t.teach('Python程序设计')



if __name__ == '__main__':
    main()
# Out:
# 王大锤 is studying 数学.
# 骆昊老叫兽正在讲Python程序设计.

# %% [markdown]
# ### 子类在继承了父类的方法后，可以对父类已有的方法给出新的实现版本，这个动作称之为方法重写（override）。通过方法重写我们可以让父类的同一个行为在子类中拥有不同的实现版本，当我们调用这个经过子类重写的方法时，不同的子类对象会表现出不同的行为，这个就是多态（poly-morphism）。

# %%
from abc import ABCMeta, abstractmethod

#将pet处理为一个抽象类，不能创造这个类的对象，只能让别的类去继承他
#如果一个类中存在抽象方法，则这个类不能实例化
class Pet(object, metaclass = ABCMeta):
    """宠物"""
    
    def __init__(self, nickname):
        self._nickname = nickname
        
    @abstractmethod
    def make_voice(self):
        """发出声音"""
        pass
    
class Dog(Pet):
    """dog"""
    
    def make_voice(self):
        print('%s: 汪汪汪...' % self._nickname)
        
class Cat(Pet):
    """猫"""

    def make_voice(self):
        print('%s: 喵...喵...' % self._nickname)


def main():
    pets = [Dog('旺财'), Cat('凯蒂'), Dog('大黄')]
    for pet in pets:
        pet.make_voice()


if __name__ == '__main__':
    main()
# Out:
# 旺财: 汪汪汪...
# 凯蒂: 喵...喵...
# 大黄: 汪汪汪...

# %%
from abc import ABCMeta, abstractmethod
from random import randint, randrange


class Fighter(object, metaclass=ABCMeta):
    """战斗者"""

    # 通过__slots__魔法限定对象可以绑定的成员变量
    __slots__ = ('_name', '_hp')

    def __init__(self, name, hp):
        """初始化方法

        :param name: 名字
        :param hp: 生命值
        """
        self._name = name
        self._hp = hp

    @property
    def name(self):
        return self._name

    @property
    def hp(self):
        return self._hp

    @hp.setter
    def hp(self, hp):
        self._hp = hp if hp >= 0 else 0

    @property
    def alive(self):
        return self._hp > 0

    @abstractmethod
    def attack(self, other):
        """攻击

        :param other: 被攻击的对象
        """
        pass


class Ultraman(Fighter):
    """奥特曼"""

    __slots__ = ('_name', '_hp', '_mp')

    def __init__(self, name, hp, mp):
        """初始化方法

        :param name: 名字
        :param hp: 生命值
        :param mp: 魔法值
        """
        super().__init__(name, hp)
        self._mp = mp

    def attack(self, other):
        other.hp -= randint(15, 25)

    def huge_attack(self, other):
        """究极必杀技(打掉对方至少50点或四分之三的血)

        :param other: 被攻击的对象

        :return: 使用成功返回True否则返回False
        """
        if self._mp >= 50:
            self._mp -= 50
            injury = other.hp * 3 // 4
            injury = injury if injury >= 50 else 50
            other.hp -= injury
            return True
        else:
            self.attack(other)
            return False

    def magic_attack(self, others):
        """魔法攻击

        :param others: 被攻击的群体

        :return: 使用魔法成功返回True否则返回False
        """
        if self._mp >= 20:
            self._mp -= 20
            for temp in others:
                if temp.alive:
                    temp.hp -= randint(10, 15)
            return True
        else:
            return False

    def resume(self):
        """恢复魔法值"""
        incr_point = randint(1, 10)
        self._mp += incr_point
        return incr_point

    def __str__(self):
        return '~~~%s奥特曼~~~\n' % self._name + \
            '生命值: %d\n' % self._hp + \
            '魔法值: %d\n' % self._mp


class Monster(Fighter):
    """小怪兽"""

    __slots__ = ('_name', '_hp')

    def attack(self, other):
        other.hp -= randint(10, 20)

    def __str__(self):
        return '~~~%s小怪兽~~~\n' % self._name + \
            '生命值: %d\n' % self._hp


def is_any_alive(monsters):
    """判断有没有小怪兽是活着的"""
    for monster in monsters:
        if monster.alive > 0:
            return True
    return False


def select_alive_one(monsters):
    """选中一只活着的小怪兽"""
    monsters_len = len(monsters)
    while True:
        index = randrange(monsters_len)
        monster = monsters[index]
        if monster.alive > 0:
            return monster


def display_info(ultraman, monsters):
    """显示奥特曼和小怪兽的信息"""
    print(ultraman)
    for monster in monsters:
        print(monster, end='')


def main():
    u = Ultraman('骆昊', 1000, 120)
    m1 = Monster('狄仁杰', 250)
    m2 = Monster('白元芳', 500)
    m3 = Monster('王大锤', 750)
    ms = [m1, m2, m3]
    fight_round = 1
    while u.alive and is_any_alive(ms):
        print('========第%02d回合========' % fight_round)
        m = select_alive_one(ms)  # 选中一只小怪兽
        skill = randint(1, 10)   # 通过随机数选择使用哪种技能
        if skill <= 6:  # 60%的概率使用普通攻击
            print('%s使用普通攻击打了%s.' % (u.name, m.name))
            u.attack(m)
            print('%s的魔法值恢复了%d点.' % (u.name, u.resume()))
        elif skill <= 9:  # 30%的概率使用魔法攻击(可能因魔法值不足而失败)
            if u.magic_attack(ms):
                print('%s使用了魔法攻击.' % u.name)
            else:
                print('%s使用魔法失败.' % u.name)
        else:  # 10%的概率使用究极必杀技(如果魔法值不足则使用普通攻击)
            if u.huge_attack(m):
                print('%s使用究极必杀技虐了%s.' % (u.name, m.name))
            else:
                print('%s使用普通攻击打了%s.' % (u.name, m.name))
                print('%s的魔法值恢复了%d点.' % (u.name, u.resume()))
        if m.alive > 0:  # 如果选中的小怪兽没有死就回击奥特曼
            print('%s回击了%s.' % (m.name, u.name))
            m.attack(u)
        display_info(u, ms)  # 每个回合结束后显示奥特曼和小怪兽的信息
        fight_round += 1
    print('\n========战斗结束!========\n')
    if u.alive > 0:
        print('%s奥特曼胜利!' % u.name)
    else:
        print('小怪兽胜利!')


if __name__ == '__main__':
    main()
# Out:
# ========第01回合========
# 骆昊使用了魔法攻击.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 989
# 魔法值: 100
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 240
# ~~~白元芳小怪兽~~~
# 生命值: 490
# ~~~王大锤小怪兽~~~
# 生命值: 739
# ========第02回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了10点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 970
# 魔法值: 110
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 240
# ~~~白元芳小怪兽~~~
# 生命值: 490
# ~~~王大锤小怪兽~~~
# 生命值: 723
# ========第03回合========
# 骆昊使用了魔法攻击.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 960
# 魔法值: 90
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 225
# ~~~白元芳小怪兽~~~
# 生命值: 476
# ~~~王大锤小怪兽~~~
# 生命值: 711
# ========第04回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了5点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 948
# 魔法值: 95
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 201
# ~~~白元芳小怪兽~~~
# 生命值: 476
# ~~~王大锤小怪兽~~~
# 生命值: 711
# ========第05回合========
# 骆昊使用了魔法攻击.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 938
# 魔法值: 75
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 191
# ~~~白元芳小怪兽~~~
# 生命值: 464
# ~~~王大锤小怪兽~~~
# 生命值: 696
# ========第06回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了4点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 923
# 魔法值: 79
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 191
# ~~~白元芳小怪兽~~~
# 生命值: 440
# ~~~王大锤小怪兽~~~
# 生命值: 696
# ========第07回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了8点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 905
# 魔法值: 87
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 191
# ~~~白元芳小怪兽~~~
# 生命值: 440
# ~~~王大锤小怪兽~~~
# 生命值: 676
# ========第08回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 894
# 魔法值: 67
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 180
# ~~~白元芳小怪兽~~~
# 生命值: 429
# ~~~王大锤小怪兽~~~
# 生命值: 662
# ========第09回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了1点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 879
# 魔法值: 68
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 157
# ~~~白元芳小怪兽~~~
# 生命值: 429
# ~~~王大锤小怪兽~~~
# 生命值: 662
# ========第10回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了6点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 865
# 魔法值: 74
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 136
# ~~~白元芳小怪兽~~~
# 生命值: 429
# ~~~王大锤小怪兽~~~
# 生命值: 662
# ========第11回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了7点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 846
# 魔法值: 81
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 136
# ~~~白元芳小怪兽~~~
# 生命值: 410
# ~~~王大锤小怪兽~~~
# 生命值: 662
# ========第12回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了7点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 829
# 魔法值: 88
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 136
# ~~~白元芳小怪兽~~~
# 生命值: 387
# ~~~王大锤小怪兽~~~
# 生命值: 662
# ========第13回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了3点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 812
# 魔法值: 91
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 114
# ~~~白元芳小怪兽~~~
# 生命值: 387
# ~~~王大锤小怪兽~~~
# 生命值: 662
# ========第14回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了9点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 799
# 魔法值: 100
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 95
# ~~~白元芳小怪兽~~~
# 生命值: 387
# ~~~王大锤小怪兽~~~
# 生命值: 662
# ========第15回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了10点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 782
# 魔法值: 110
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 95
# ~~~白元芳小怪兽~~~
# 生命值: 367
# ~~~王大锤小怪兽~~~
# 生命值: 662
# ========第16回合========
# 骆昊使用了魔法攻击.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 770
# 魔法值: 90
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 83
# ~~~白元芳小怪兽~~~
# 生命值: 352
# ~~~王大锤小怪兽~~~
# 生命值: 651
# ========第17回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了4点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 751
# 魔法值: 94
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 83
# ~~~白元芳小怪兽~~~
# 生命值: 331
# ~~~王大锤小怪兽~~~
# 生命值: 651
# ========第18回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了5点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 733
# 魔法值: 99
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 64
# ~~~白元芳小怪兽~~~
# 生命值: 331
# ~~~王大锤小怪兽~~~
# 生命值: 651
# ========第19回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了7点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 717
# 魔法值: 106
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 48
# ~~~白元芳小怪兽~~~
# 生命值: 331
# ~~~王大锤小怪兽~~~
# 生命值: 651
# ========第20回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了1点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 706
# 魔法值: 107
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 23
# ~~~白元芳小怪兽~~~
# 生命值: 331
# ~~~王大锤小怪兽~~~
# 生命值: 651
# ========第21回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了3点.
# 狄仁杰回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 686
# 魔法值: 110
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 3
# ~~~白元芳小怪兽~~~
# 生命值: 331
# ~~~王大锤小怪兽~~~
# 生命值: 651
# ========第22回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了8点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 671
# 魔法值: 118
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 3
# ~~~白元芳小怪兽~~~
# 生命值: 316
# ~~~王大锤小怪兽~~~
# 生命值: 651
# ========第23回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了7点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 652
# 魔法值: 125
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 3
# ~~~白元芳小怪兽~~~
# 生命值: 292
# ~~~王大锤小怪兽~~~
# 生命值: 651
# ========第24回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了6点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 638
# 魔法值: 131
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 3
# ~~~白元芳小怪兽~~~
# 生命值: 292
# ~~~王大锤小怪兽~~~
# 生命值: 626
# ========第25回合========
# 骆昊使用普通攻击打了狄仁杰.
# 骆昊的魔法值恢复了5点.
# ~~~骆昊奥特曼~~~
# 生命值: 638
# 魔法值: 136
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 292
# ~~~王大锤小怪兽~~~
# 生命值: 626
# ========第26回合========
# 骆昊使用究极必杀技虐了王大锤.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 618
# 魔法值: 86
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 292
# ~~~王大锤小怪兽~~~
# 生命值: 157
# ========第27回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了5点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 604
# 魔法值: 91
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 267
# ~~~王大锤小怪兽~~~
# 生命值: 157
# ========第28回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了2点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 584
# 魔法值: 93
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 244
# ~~~王大锤小怪兽~~~
# 生命值: 157
# ========第29回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了5点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 566
# 魔法值: 98
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 244
# ~~~王大锤小怪兽~~~
# 生命值: 133
# ========第30回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了9点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 550
# 魔法值: 107
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 227
# ~~~王大锤小怪兽~~~
# 生命值: 133
# ========第31回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了1点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 540
# 魔法值: 108
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 227
# ~~~王大锤小怪兽~~~
# 生命值: 108
# ========第32回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了6点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 525
# 魔法值: 114
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 227
# ~~~王大锤小怪兽~~~
# 生命值: 83
# ========第33回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了4点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 508
# 魔法值: 118
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 208
# ~~~王大锤小怪兽~~~
# 生命值: 83
# ========第34回合========
# 骆昊使用究极必杀技虐了王大锤.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 490
# 魔法值: 68
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 208
# ~~~王大锤小怪兽~~~
# 生命值: 21
# ========第35回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了1点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 472
# 魔法值: 69
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 191
# ~~~王大锤小怪兽~~~
# 生命值: 21
# ========第36回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了6点.
# 王大锤回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 456
# 魔法值: 75
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 191
# ~~~王大锤小怪兽~~~
# 生命值: 6
# ========第37回合========
# 骆昊使用普通攻击打了王大锤.
# 骆昊的魔法值恢复了10点.
# ~~~骆昊奥特曼~~~
# 生命值: 456
# 魔法值: 85
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 191
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第38回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了8点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 442
# 魔法值: 93
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 173
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第39回合========
# 骆昊使用了魔法攻击.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 431
# 魔法值: 73
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 161
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第40回合========
# 骆昊使用了魔法攻击.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 411
# 魔法值: 53
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 149
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第41回合========
# 骆昊使用了魔法攻击.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 395
# 魔法值: 33
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 139
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第42回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了10点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 385
# 魔法值: 43
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 121
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第43回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了9点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 373
# 魔法值: 52
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 103
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第44回合========
# 骆昊使用了魔法攻击.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 356
# 魔法值: 32
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 90
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第45回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了1点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 343
# 魔法值: 33
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 68
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第46回合========
# 骆昊使用了魔法攻击.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 331
# 魔法值: 13
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 55
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第47回合========
# 骆昊使用魔法失败.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 318
# 魔法值: 13
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 55
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第48回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了6点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 304
# 魔法值: 19
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 35
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第49回合========
# 骆昊使用普通攻击打了白元芳.
# 骆昊的魔法值恢复了2点.
# 白元芳回击了骆昊.
# ~~~骆昊奥特曼~~~
# 生命值: 288
# 魔法值: 21
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 13
# ~~~王大锤小怪兽~~~
# 生命值: 0
# ========第50回合========
# 骆昊使用了魔法攻击.
# ~~~骆昊奥特曼~~~
# 生命值: 288
# 魔法值: 1
#
# ~~~狄仁杰小怪兽~~~
# 生命值: 0
# ~~~白元芳小怪兽~~~
# 生命值: 0
# ~~~王大锤小怪兽~~~
# 生命值: 0
#
# ========战斗结束!========
#
# 骆昊奥特曼胜利!

# %%
import random


class Card(object):
    """一张牌"""

    def __init__(self, suite, face):
        self._suite = suite
        self._face = face

    @property
    def face(self):
        return self._face

    @property
    def suite(self):
        return self._suite

    def __str__(self):
        if self._face == 1:
            face_str = 'A'
        elif self._face == 11:
            face_str = 'J'
        elif self._face == 12:
            face_str = 'Q'
        elif self._face == 13:
            face_str = 'K'
        else:
            face_str = str(self._face)
        return '%s%s' % (self._suite, face_str)
    
    def __repr__(self):
        return self.__str__()


class Poker(object):
    """一副牌"""

    def __init__(self):
        self._cards = [Card(suite, face) 
                       for suite in '♠♥♣♦'
                       for face in range(1, 14)]
        self._current = 0

    @property
    def cards(self):
        return self._cards

    def shuffle(self):
        """洗牌(随机乱序)"""
        self._current = 0
        random.shuffle(self._cards)

    @property
    def next(self):
        """发牌"""
        card = self._cards[self._current]
        self._current += 1
        return card

    @property
    def has_next(self):
        """还有没有牌"""
        return self._current < len(self._cards)


class Player(object):
    """玩家"""

    def __init__(self, name):
        self._name = name
        self._cards_on_hand = []

    @property
    def name(self):
        return self._name

    @property
    def cards_on_hand(self):
        return self._cards_on_hand

    def get(self, card):
        """摸牌"""
        self._cards_on_hand.append(card)

    def arrange(self, card_key):
        """玩家整理手上的牌"""
        self._cards_on_hand.sort(key=card_key)


# 排序规则-先根据花色再根据点数排序
def get_key(card):
    return (card.suite, card.face)


def main():
    p = Poker()
    p.shuffle()
    players = [Player('东邪'), Player('西毒'), Player('南帝'), Player('北丐')]
    for _ in range(13):
        for player in players:
            player.get(p.next)
    for player in players:
        print(player.name + ':', end=' ')
        player.arrange(get_key)
        print(player.cards_on_hand)


if __name__ == '__main__':
    main()
# Out:
# 东邪: [♠J, ♣6, ♣8, ♣J, ♥5, ♥6, ♥7, ♥8, ♥10, ♥J, ♦10, ♦J, ♦Q]
# 西毒: [♠2, ♠4, ♠9, ♠K, ♣7, ♣9, ♣10, ♣K, ♥9, ♦A, ♦5, ♦6, ♦8]
# 南帝: [♠5, ♠6, ♠7, ♠10, ♠Q, ♣A, ♣Q, ♥A, ♥Q, ♥K, ♦2, ♦3, ♦K]
# 北丐: [♠A, ♠3, ♠8, ♣2, ♣3, ♣4, ♣5, ♥2, ♥3, ♥4, ♦4, ♦7, ♦9]

# %%
"""
某公司有三种类型的员工 分别是部门经理、程序员和销售员
需要设计一个工资结算系统 根据提供的员工信息来计算月薪
部门经理的月薪是每月固定15000元
程序员的月薪按本月工作时间计算 每小时150元
销售员的月薪是1200元的底薪加上销售额5%的提成
"""

from abc import ABCMeta, abstractmethod

class Employee(object, metaclass = ABCMeta):
    """Employee"""
    
    
    def __init__(self, name):
        """
        initial method
        
        :param name: name
        """
        self._name = name
        
    @property
    def name(self):
        return self._name
    
    @abstractmethod
    def get_salary(self):
        pass
    
    
class Manager(Employee):
    
    
    def get_salary(self):
        return 15000

class Programmer(Employee):
    
    def __init__(self, name, worktime = 0):
        super().__init__(name)
        self._worktime = worktime
        
    @property
    def worktime(self):
        return self._worktime
    
    @worktime.setter
    def worktime(self, worktime):
        self._worktime = worktime if worktime >= 0 else 0
        
    
    def get_salary(self):
        return 150 * self._worktime
    
    
class Salesman(Employee):
    def __init__(self, name, sales = 0):
        super().__init__(name)
        self._sales = sales
        
    @property
    def sales(self):
        return self._sales
    
    @sales.setter
    def sales(self, sales):
        self._sales = sales if sales >= 0 else 0
        
    def get_salary(self):
        return 1200 + 0.05 * self._sales
        
def main():
    emps = [
        Manager('刘备'), Programmer('诸葛亮'),
        Manager('曹操'), Salesman('荀彧'),
        Salesman('吕布'), Programmer('张辽'),
        Programmer('赵云')
    ]
    for emp in emps:
        if isinstance(emp, Programmer):
            emp.worktime = int(input('请输入%s本月工作时间: ' % emp.name))
        elif isinstance(emp, Salesman):
            emp.sales = float(input('请输入%s本月销售额: ' % emp.name))
        # 同样是接收get_salary这个消息但是不同的员工表现出了不同的行为(多态)
        print('%s本月工资为: ￥%s元' %
              (emp.name, emp.get_salary()))


if __name__ == '__main__':
    main()
# Out:
# 刘备本月工资为: ￥15000元
# 请输入诸葛亮本月工作时间: 345
# 诸葛亮本月工资为: ￥51750元
# 曹操本月工资为: ￥15000元
# 请输入荀彧本月销售额: 2222
# 荀彧本月工资为: ￥1311.1元
# 请输入吕布本月销售额: 22222
# 吕布本月工资为: ￥2311.1000000000004元
# 请输入张辽本月工作时间: 1234
# 张辽本月工资为: ￥185100元
# 请输入赵云本月工作时间: 56
# 赵云本月工资为: ￥8400元

# %%
from abc import ABCMeta, abstractmethod


class Employee(object, metaclass=ABCMeta):
    """员工"""

    def __init__(self, name):
        """
        初始化方法

        :param name: 姓名
        """
        self._name = name

    @property
    def name(self):
        return self._name

    @abstractmethod
    def get_salary(self):
        """
        获得月薪

        :return: 月薪
        """
        pass


class Manager(Employee):
    """部门经理"""

    def get_salary(self):
        return 15000.0


class Programmer(Employee):
    """程序员"""

    def __init__(self, name, working_hour=0):
        super().__init__(name)
        self._working_hour = working_hour

    @property
    def working_hour(self):
        return self._working_hour

    @working_hour.setter
    def working_hour(self, working_hour):
        self._working_hour = working_hour if working_hour > 0 else 0

    def get_salary(self):
        return 150.0 * self._working_hour


class Salesman(Employee):
    """销售员"""

    def __init__(self, name, sales=0):
        super().__init__(name)
        self._sales = sales

    @property
    def sales(self):
        return self._sales

    @sales.setter
    def sales(self, sales):
        self._sales = sales if sales > 0 else 0

    def get_salary(self):
        return 1200.0 + self._sales * 0.05


def main():
    emps = [
        Manager('刘备'), Programmer('诸葛亮'),
        Manager('曹操'), Salesman('荀彧'),
        Salesman('吕布'), Programmer('张辽'),
        Programmer('赵云')
    ]
    for emp in emps:
        if isinstance(emp, Programmer):
            emp.working_hour = int(input('请输入%s本月工作时间: ' % emp.name))
        elif isinstance(emp, Salesman):
            emp.sales = float(input('请输入%s本月销售额: ' % emp.name))
        # 同样是接收get_salary这个消息但是不同的员工表现出了不同的行为(多态)
        print('%s本月工资为: ￥%s元' %
              (emp.name, emp.get_salary()))


if __name__ == '__main__':
    main()
# Out:
# 刘备本月工资为: ￥15000.0元
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     877             try:
# --> 878                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     879             except Exception:
#
# /anaconda3/lib/python3.7/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /anaconda3/lib/python3.7/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     469         """
# --> 470         parts = [self.recv(flags, copy=copy, track=track)]
#     471         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /anaconda3/lib/python3.7/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-4dcede66d3ad> in <module>
#      90
#      91 if __name__ == '__main__':
# ---> 92     main()
#
# <ipython-input-78-4dcede66d3ad> in main()
#      81     for emp in emps:
#      82         if isinstance(emp, Programmer):
# ---> 83             emp.working_hour = int(input('请输入%s本月工作时间: ' % emp.name))
#      84         elif isinstance(emp, Salesman):
#      85             emp.sales = float(input('请输入%s本月销售额: ' % emp.name))
#
# /anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     851             self._parent_ident,
#     852             self._parent_header,
# --> 853             password=False,
#     854         )
#     855
#
# /anaconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     881             except KeyboardInterrupt:
#     882                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 883                 raise KeyboardInterrupt
#     884             else:
#     885                 break
#
# KeyboardInterrupt:
